# %%
import numpy as np
import scipy.linalg as linalg
import matplotlib.pyplot as plt
import pandas as pd
from scipy.spatial.distance import pdist, cdist

# %%
#Linear
from sklearn.linear_model import LinearRegression
#linear LARS
from sklearn import linear_model
#DL model
from sklearn.neural_network import MLPRegressor

#DLEDMD
import tensorflow as tf
import DLEDMD
import MLP

# %%
#MSE and NSE
def MSE(x,y):
    return np.sqrt(np.mean(np.square(x-y)))

def NSE(pre,tar):
    a=np.sum(np.square(pre-tar))/np.sum(np.square(tar-np.mean(tar)))
    return 1-a

# %%
def Pre_data():
    #Prepare training data (set0)
    df_s0 = pd.read_excel(r'./save_data/excelfile/rain0_set0_state_data.xlsx')
    df_a0= pd.read_excel(r'./save_data/excelfile/rain0_set0_action_data.xlsx')
    df_r0= pd.read_excel(r'./save_data/excelfile/rain0_set0_rain_data.xlsx')
    dt_s0=df_s0.values[:1,1:]
    dt_a0=df_a0.values[:1,1:]
    dt_r0=df_r0.values[:1,1:]
    
    data=np.concatenate((dt_s0,dt_a0,dt_r0),axis=1)
    for it in [0,2,4,6,8,9]:
        for jt in [0,1,2]:   
            df_s0 = pd.read_excel(r'./save_data/excelfile/rain'+str(it)+'_set'+str(jt)+'_state_data.xlsx')
            df_a0= pd.read_excel(r'./save_data/excelfile/rain'+str(it)+'_set'+str(jt)+'_action_data.xlsx')
            df_r0= pd.read_excel(r'./save_data/excelfile/rain'+str(it)+'_set'+str(jt)+'_rain_data.xlsx')
            dt_s0=df_s0.values[:,1:]
            dt_a0=df_a0.values[:,1:]
            dt_r0=df_r0.values[:,1:]
            tem=np.concatenate((dt_s0,dt_a0,dt_r0),axis=1)
            data=np.concatenate((data,tem),axis=0)
    
    data=data[1:,:]
            
    #Prepare test1 data
    df_s0 = pd.read_excel(r'./save_data/excelfile/rain0_set1_state_data.xlsx')
    df_a0= pd.read_excel(r'./save_data/excelfile/rain0_set1_action_data.xlsx')
    df_r0= pd.read_excel(r'./save_data/excelfile/rain0_set1_rain_data.xlsx')
    dt_s0=df_s0.values[:,1:]
    dt_a0=df_a0.values[:,1:]
    dt_r0=df_r0.values[:,1:]
    data_test1=[]
    data_test1.append(np.concatenate((dt_s0,dt_a0,dt_r0),axis=1))
    for it in [3,5,7]:
        for jt in [1]:   
            df_s0 = pd.read_excel(r'./save_data/excelfile/rain'+str(it)+'_set'+str(jt)+'_state_data.xlsx')
            df_a0= pd.read_excel(r'./save_data/excelfile/rain'+str(it)+'_set'+str(jt)+'_action_data.xlsx')
            df_r0= pd.read_excel(r'./save_data/excelfile/rain'+str(it)+'_set'+str(jt)+'_rain_data.xlsx')
            dt_s0=df_s0.values[:,1:]
            dt_a0=df_a0.values[:,1:]
            dt_r0=df_r0.values[:,1:]
            tem=np.concatenate((dt_s0,dt_a0,dt_r0),axis=1)
            data_test1.append(tem)
    
    #Prepare training data2 (set0)
    df_s0 = pd.read_excel(r'./save_data/excelfile/rain0_set0_state_data.xlsx')
    df_a0= pd.read_excel(r'./save_data/excelfile/rain0_set0_action_data.xlsx')
    df_r0= pd.read_excel(r'./save_data/excelfile/rain0_set0_rain_data.xlsx')
    dt_s0=df_s0.values[:,1:]
    dt_a0=df_a0.values[:,1:]
    dt_r0=df_r0.values[:,1:]
    
    return data,data_test1

data,data_test1=Pre_data()
print(data.shape)
# Out:
# (1080, 13)

# %% [markdown]
# # 5.1 Results

# %% [markdown]
# # Linear

# %%
#linear
X_train=data[:data.shape[0]-2,:]
Y_train=data[1:data.shape[0]-1,:4]
print(X_train.shape,Y_train.shape)

linear = LinearRegression()
linear.fit(X_train,Y_train)
# Out:
# (1078, 13) (1078, 4)
# LinearRegression()

# %% [markdown]
# # MLP

# %% [markdown]
# ## Sklearn

# %% [raw]
# import pickle
# X_train=data[:data.shape[0]-2,:]
# Y_train=data[1:data.shape[0]-1,:4]
#
# #MLP
# MLP_model = MLPRegressor(hidden_layer_sizes=(10,10,4),  activation='relu', learning_rate=1e-4, max_iter=50000,epsilon=1e-9,solver='adam')
#
# ep=5000
# for _ in range(ep):
#     MLP.fit(X_train,Y_train)
#
# s=pickle.dumps(MLP)
# with open('./emulator_model/MLP_emulator_model/MLP3.model','wb+') as f:
#     f.write(s)
#
# f=open('./emulator_model/MLP_emulator_model/MLP2.model','rb')
# s=f.read()
# MLP_model=pickle.loads(s)
#
#
# i=2
# X_test=data_test1[i][:46,:]
# Y_test=data_test1[i][1:47,:4]
# y=np.zeros(Y_test.shape)
# print(y.shape,Y_test.shape,X_test.shape)
#
# X=X_test.copy()
# for t in np.arange(45):
#     ytem=MLP_model.predict(X[t].reshape((1,-1)))
#     y[t,:]=ytem
#     X[t+1,:4]=ytem
#
# for j in range(4):
#     plt.figure()
#     plt.plot(y[:45,j],'r')
#     plt.plot(Y_test[:45,j],'b')
#
#
# i=3
# X_test=data_test1[i][:46,:]
# Y_test=data_test1[i][1:47,:4]
# y=MLP.predict(X_test)
#
# for j in range(4):
#     plt.figure()
#     plt.plot(y[:45,j],'r')
#     plt.plot(Y_test[:45,j],'b')

# %% [markdown]
# ## Tensorflow

# %%
X_train=data[:data.shape[0]-2,:4]
X_train_F=data[:data.shape[0]-2,4:]
Y_train=data[1:data.shape[0]-1,:4]

gM=tf.Graph()
with gM.as_default():
    
    params={}
    params['layers']=[[4+9,10],[10,50],[50,10],[10,4]]
    params['input_layer']=4#X_train.shape[1]
    params['f_layer']=9#X_train_F.shape[1]
    params['output_layer']=4#Y_train.shape[1]
    params['lr']=0.0000005
    MLP_model=MLP.MLP(params,X_train,Y_train,X_train_F)
    MLPybar=MLP_model.forward_net(MLP_model.x,MLP_model.f)
    MLPloss=MLP_model.Loss(MLP_model.x,MLP_model.f,MLP_model.y)
    MLPop=MLP_model.opt(MLPloss)
    MLPsess=tf.compat.v1.Session()
    
    #init_op = tf.compat.v1.global_variables_initializer()
    #sess.run(init_op)
    
    saver = tf.compat.v1.train.Saver()
    saver.restore(MLPsess,'./emulator_model/MLP_emulator_model/MLP_model10.ckpt')
    
    '''
    epoch=20000
    r1,r2=[],[]
    for step in np.arange(epoch):
        for i in np.arange(10):
            sess.run(op,feed_dict={model.x:X_train,model.f:X_train_F,model.y:Y_train})
        r1.append(sess.run(loss,feed_dict={model.x:X_train,model.f:X_train_F,model.y:Y_train}))
        #r2.append(sess.run(model.Loss,feed_dict={model.x:X_test,model.y_bar:Y_test,model.f:X_test_F}))

    plt.plot(r1)
    print(np.min(r1))
    saver=tf.compat.v1.train.Saver()
    sp=saver.save(sess,'./emulator_model/MLP_emulator_model/MLP_model12.ckpt') 
    '''
# Out:
# INFO:tensorflow:Restoring parameters from ./emulator_model/MLP_emulator_model/MLP_model10.ckpt

# %%
i=0
X_test=data_test1[i][:46,:4]
X_test_F=data_test1[i][:46,4:]
Y_test=data_test1[i][1:47,:4]
print(X_test.shape,X_test_F.shape,Y_test.shape)
# Out:
# (46, 4) (46, 9) (46, 4)

# %%
i=0
X_test=data_test1[i][:46,:4]
X_test_F=data_test1[i][:46,4:]
Y_test=data_test1[i][1:47,:4]
y=np.zeros(Y_test.shape)

X=X_test.copy()
F=X_test_F.copy()
xt=X[0]
for t in np.arange(46):
    ytem=MLPsess.run(MLPybar,feed_dict={MLP_model.x:xt.reshape((1,-1)),MLP_model.f:F[t].reshape((1,-1))})
    y[t,:]=ytem
    xt=ytem

for j in np.arange(4):
    plt.figure()
    plt.plot(y[:,j],'r')
    plt.plot(Y_test[:,j],'b')

# %%
i=2
X_test=data_test1[i][:46,:4]
X_test_F=data_test1[i][:46,4:]
Y_test=data_test1[i][1:47,:4]
y=MLPsess.run(MLPybar,feed_dict={MLP_model.x:X_test,MLP_model.f:X_test_F})

for j in np.arange(4):
    plt.figure()
    plt.plot(y[:,j],'r')
    plt.plot(Y_test[:,j],'b')

# %% [markdown]
# # DLEDMD

# %%
X_train=data[:data.shape[0]-2,:4]
X_train_F=data[:data.shape[0]-2,4:]
Y_train=data[1:data.shape[0]-1,:4]

params={}
params['enlayers']=[[4+9,10],[10,50],[50,100],[100,100]]
params['K']=[100,100]
params['delayers']=[[100,100],[100,50],[50,10],[10,4]]

params['input_layer']=4#X_train.shape[1]
params['f_layer']=9#X_train_F.shape[1]
params['output_layer']=4#Y_train.shape[1]
params['lr']=0.0001


model=DLEDMD.DLEDMD(params,X_train,Y_train,X_train_F)
ybar=model.forward_net(model.x,model.f)
loss=model.Loss(model.x,model.f,model.y)
op=model.opt(loss)
sess=tf.compat.v1.Session()

# %%
init_op = tf.compat.v1.global_variables_initializer()
sess.run(init_op)
saver = tf.compat.v1.train.Saver()
r1,r2=[],[]

# %%
epoch=20000
r1,r2=[],[]
for step in np.arange(epoch):
    #if np.mod(step,50)==0 and step!=0:
    #    saver.save(sess, "model/model.ckpt")
    #Through batch
    '''
    for i in np.arange(len(data1)):
        X_train=data1[i][:46,:4]
        X_train_F=data1[i][:46,4:]
        Y_train=data1[i][1:47,:4]
        sess.run(op,feed_dict={model.x:X_train,model.f:X_train_F,model.y:Y_train})
    '''
    
    for i in np.arange(10):
        sess.run(op,feed_dict={model.x:X_train,model.f:X_train_F,model.y:Y_train})
    r1.append(sess.run(loss,feed_dict={model.x:X_train,model.f:X_train_F,model.y:Y_train}))
    #r2.append(sess.run(model.Loss,feed_dict={model.x:X_test,model.y_bar:Y_test,model.f:X_test_F}))
    
plt.plot(r1)
print(np.min(r1))
saver=tf.compat.v1.train.Saver()
sp=saver.save(sess,'./emulator_model/DLEDMD_emulator_model/DLEDMD_model.ckpt')
# Out:
# 0.0019585700846822193

# %%
X_train=data[:data.shape[0]-2,:4]
X_train_F=data[:data.shape[0]-2,4:]
Y_train=data[1:data.shape[0]-1,:4]

g2=tf.Graph()
with g2.as_default():
    params={}
    params['enlayers']=[[4+9,10],[10,50],[50,100],[100,100]]
    params['K']=[100,100]
    params['delayers']=[[100,100],[100,50],[50,10],[10,4]]

    params['input_layer']=4#X_train.shape[1]
    params['f_layer']=9#X_train_F.shape[1]
    params['output_layer']=4#Y_train.shape[1]
    params['lr']=0.0001


    model=DLEDMD.DLEDMD(params,X_train,Y_train,X_train_F)
    ybar=model.forward_net(model.x,model.f)
    loss=model.Loss(model.x,model.f,model.y)
    op=model.opt(loss)
    sess=tf.compat.v1.Session()
    
    saver = tf.compat.v1.train.Saver()
    
    saver.restore(sess,'./emulator_model/DLEDMD_emulator_model/DLEDMD_model.ckpt')
# Out:
# INFO:tensorflow:Restoring parameters from ./emulator_model/DLEDMD_emulator_model/DLEDMD_model.ckpt

# %%
X_test=data_test1[i][:46,:4]
X_test_F=data_test1[i][:46,4:]
Y_test=data_test1[i][1:47,:4]
print(X_test.shape,X_test_F.shape,Y_test.shape)
# Out:
# (46, 4) (46, 9) (46, 4)

# %%
i=0
X_test=data_test1[i][:46,:4]
X_test_F=data_test1[i][:46,4:]
Y_test=data_test1[i][1:47,:4]
y=np.zeros(Y_test.shape)

X=X_test.copy()
F=X_test_F.copy()

xt=X[0]
for t in np.arange(46):
    ytem=sess.run(ybar,feed_dict={model.x:xt.reshape((1,-1)),model.f:F[t].reshape((1,-1))})
    y[t,:]=ytem
    xt=ytem

for j in np.arange(4):
    plt.figure()
    plt.plot(y[:,j],'r')
    plt.plot(Y_test[:,j],'b')

# %% [markdown]
# # Results of Emulation

# %% [markdown]
# ## Prediction (full rainfall prediction)

# %%
#Prediction 4 rainfall for testing
#Prediction
Linear,GP,ml,dle,SWMM=[],[],[],[],[]
for i in range(4):
    #X_test, Y_test=data_test1[rainlog][:46,:],data_test1[0][1:47,:]
    X_test=data_test1[i][:46,:]
    Y_test=data_test1[i][1:47,:4]
    
    #X_test=data_test1[i][:46,:4]
    #X_test_F=data_test1[i][:46,4:]
    #Y_test=data_test1[i][1:47,:4]
    
    print('Rain number:',i)
    
    print('Linear:')
    y_L=np.zeros(Y_test.shape)
    X=X_test.copy()
    for t in np.arange(Y_test.shape[0]-1):
        ytem=linear.predict(X[t].reshape((1,-1)))  
        y_L[t,:]=ytem
        if t+1<Y_test.shape[0]:
            X[t+1,:4]=ytem
    print('MSE:',MSE(y_L,Y_test),'  NSE:',NSE(y_L,Y_test))
    
    print('MLP:')
    y_M=np.zeros((Y_test.shape[0]-1,Y_test.shape[1])) 
    X=X_test[:46,:4].copy()
    F=X_test[:46,4:].copy()
    xt=X[0]
    for t in np.arange(Y_test.shape[0]-1):
        ytem=MLPsess.run(MLPybar,feed_dict={MLP_model.x:xt.reshape((1,-1)),MLP_model.f:F[t].reshape((1,-1))})
        y_M[t,:]=ytem
        xt=ytem
    print('MSE:',MSE(y_M,Y_test[:-1]),'  NSE:',NSE(y_M,Y_test[:-1]))
    
    print('DLEDMD:')
    y_D=np.zeros((Y_test.shape[0]-1,Y_test.shape[1]))
    X=X_test.copy()[:46,:4]
    F=X_test.copy()[:46,4:]
    xt=X[0]
    for t in np.arange(Y_test.shape[0]-1):
        ytem=sess.run(ybar,feed_dict={model.x:xt.reshape((1,-1)),model.f:F[t].reshape((1,-1))})
        y_D[t,:]=ytem
        if t+1<Y_test.shape[0]:
            xt=ytem
    print('MSE:',MSE(y_D,Y_test[:-1]),'  NSE:',NSE(y_D,Y_test[:-1]))

    Linear.append(y_L)
    dle.append(y_D)
    GP.append(y_G)
    ml.append(y_M)
    SWMM.append(Y_test)
# Out:
# Rain number: 0
# Linear:
# MSE: 3.860292693719178   NSE: 0.8510578014360373
# MLP:
# MSE: 1.8797384534356294   NSE: 0.963825490090462
# DLEDMD:
# MSE: 0.7664346253530089   NSE: 0.993986074581942
# Rain number: 1
# Linear:
# MSE: 5.798419736503392   NSE: 0.6852134283721228
# MLP:
# MSE: 4.3718090866803925   NSE: 0.8167970153379347
# DLEDMD:
# MSE: 2.32008812412854   NSE: 0.9484036321892172
# Rain number: 2
# Linear:
# MSE: 9.86748690950834   NSE: 0.006944948572546461
# MLP:
# MSE: 2.716504640560799   NSE: 0.9229740773634417
# DLEDMD:
# MSE: 2.5558001933141044   NSE: 0.9318179893983681
# Rain number: 3
# Linear:
# MSE: 5.980748981766306   NSE: 0.6430403601190079
# MLP:
# MSE: 2.6213419484874407   NSE: 0.9298042229319718
# DLEDMD:
# MSE: 1.8975523042720666   NSE: 0.9632166616091974

# %% [markdown]
# ## Regression (one step prediction)

# %%
LinearR,GPR,MLPR,DLEDMDR,SWMMR=[],[],[],[],[]
for i in range(4):
    #X_test, Y_test=data_test1[rainlog][:46,:],data_test1[0][1:47,:]
    X_test=data_test1[i][:47,:]
    Y_test=data_test1[i][1:48,:4]
    
    print('Rain number:',i)
    
    print('Linear:')
    y_L=np.zeros(Y_test.shape)
    X=X_test.copy()
    for t in np.arange(Y_test.shape[0]):
        ytem=linear.predict(X[t].reshape((1,-1)))  
        y_L[t,:]=ytem
        
    print('MSE:',MSE(y_L,Y_test),'  NSE:',NSE(y_L,Y_test))
    
    print('MLP:')
    y_M=np.zeros((Y_test.shape[0]-1,Y_test.shape[1]))
    X=X_test.copy()[:46,:4]
    F=X_test.copy()[:46,4:]
    y_M=MLPsess.run(MLPybar,feed_dict={MLP_model.x:X,MLP_model.f:F})
    
    print('MSE:',MSE(y_M,Y_test[:-1]),'  NSE:',NSE(y_M,Y_test[:-1]))
    
    print('DLEDMD:')
    y_D=np.zeros((Y_test.shape[0]-1,Y_test.shape[1]))
    X=X_test.copy()[:46,:4]
    F=X_test.copy()[:46,4:]
    y_D=sess.run(ybar,feed_dict={model.x:X,model.f:F})

    print('MSE:',MSE(y_D,Y_test[:-1]),'  NSE:',NSE(y_D,Y_test[:-1]))

    LinearR.append(y_L)
    DLEDMDR.append(y_D)
    GPR.append(y_G)
    MLPR.append(y_M)
    SWMMR.append(Y_test)
# Out:
# Rain number: 0
# Linear:
# MSE: 0.6674843054810058   NSE: 0.9956480205551571
# MLP:
# MSE: 0.10692978026161926   NSE: 0.9998857188401847
# DLEDMD:
# MSE: 0.13700174803676304   NSE: 0.9998124014369497
# Rain number: 1
# Linear:
# MSE: 0.619445402845917   NSE: 0.9964868199782397
# MLP:
# MSE: 0.7881268335926971   NSE: 0.9941844723291513
# DLEDMD:
# MSE: 0.32210404416596333   NSE: 0.999028619785998
# Rain number: 2
# Linear:
# MSE: 0.6103516891482784   NSE: 0.9962834958360693
# MLP:
# MSE: 0.2177612641900024   NSE: 0.9995163608321025
# DLEDMD:
# MSE: 0.08544593987050829   NSE: 0.9999255365644677
# Rain number: 3
# Linear:
# MSE: 0.6574333255472324   NSE: 0.9957816267097472
# MLP:
# MSE: 0.16502139750339698   NSE: 0.9997282381526104
# DLEDMD:
# MSE: 0.09657566713527913   NSE: 0.9999069227810435

# %%
for j in range(4):
    if True:
        pd.DataFrame(Linear[j][:,:4]).to_excel('./results/Prediction/Linear'+str(j)+'.xlsx', index=False)
        pd.DataFrame(dle[j][:,:4]).to_excel('./results/Prediction/DLEDMD'+str(j)+'.xlsx', index=False)
        pd.DataFrame(ml[j][:,:4]).to_excel('./results/Prediction/MLP'+str(j)+'.xlsx', index=False)
        pd.DataFrame(SWMM[j][:,:4]).to_excel('./results/Prediction/SWMM'+str(j)+'.xlsx', index=False)

# %%
for j in range(4):
    if True:
        pd.DataFrame(LinearR[j][:,:4]).to_excel('./results/Regression/Linear'+str(j)+'.xlsx', index=False)
        pd.DataFrame(DLEDMDR[j][:,:4]).to_excel('./results/Regression/DLEDMD'+str(j)+'.xlsx', index=False)
        pd.DataFrame(MLPR[j][:,:4]).to_excel('./results/Regression/MLP'+str(j)+'.xlsx', index=False)
        pd.DataFrame(SWMMR[j][:,:4]).to_excel('./results/Regression/SWMM'+str(j)+'.xlsx', index=False)
